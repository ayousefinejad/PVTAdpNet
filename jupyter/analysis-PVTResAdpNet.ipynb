# %%
# Train Metrics
train_loss = [0.7785, 0.5121, 0.4434, 0.3559, 0.3097, 0.2573, 0.2425, 0.2284, 0.1969, 0.1887, 
              0.1924, 0.1893, 0.1575, 0.1314, 0.1194, 0.1237, 0.1253, 0.1094, 0.1068, 0.1201, 
              0.1031, 0.1173, 0.1080, 0.1129, 0.1033]

train_jaccard = [0.6180, 0.7389, 0.7624, 0.7887, 0.8073, 0.8190, 0.8252, 0.8336, 0.8476, 0.8512, 
                 0.8501, 0.8538, 0.8613, 0.8801, 0.8834, 0.8830, 0.8846, 0.8904, 0.8942, 0.8908, 
                 0.8948, 0.8936, 0.8944, 0.8924, 0.8953]

train_f1 = [0.7318, 0.8305, 0.8469, 0.8663, 0.8798, 0.8886, 0.8932, 0.8990, 0.9086, 0.9100, 
            0.9105, 0.9127, 0.9178, 0.9310, 0.9325, 0.9330, 0.9334, 0.9384, 0.9409, 0.9374, 
            0.9414, 0.9398, 0.9404, 0.9389, 0.9406]

train_recall = [0.8451, 0.8520, 0.8470, 0.8656, 0.8709, 0.8811, 0.8794, 0.8874, 0.8958, 0.8992, 
                0.8950, 0.8983, 0.9062, 0.9183, 0.9168, 0.9201, 0.9204, 0.9239, 0.9276, 0.9254, 
                0.9268, 0.9274, 0.9283, 0.9281, 0.9291]

train_precision = [0.7159, 0.8620, 0.8916, 0.9033, 0.9174, 0.9259, 0.9315, 0.9342, 0.9391, 0.9404, 
                   0.9444, 0.9468, 0.9430, 0.9552, 0.9602, 0.9552, 0.9573, 0.9603, 0.9610, 0.9573, 
                   0.9630, 0.9596, 0.9599, 0.9560, 0.9604]

# Validation Metrics
val_loss = [0.5628, 0.5576, 0.6150, 0.6007, 0.3023, 0.3391, 0.2901, 0.3183, 0.3995, 0.3026, 
            0.3792, 0.4153, 0.3068, 0.2805, 0.3415, 0.3277, 0.3607, 0.3630, 0.3874, 0.3182, 
            0.3195, 0.3660, 0.3404, 0.3674, 0.3708]

val_jaccard = [0.7514, 0.7640, 0.7804, 0.7787, 0.7883, 0.8108, 0.7967, 0.7993, 0.8159, 0.7970, 
               0.8093, 0.8192, 0.8251, 0.8294, 0.8330, 0.8355, 0.8322, 0.8338, 0.8370, 0.8356, 
               0.8368, 0.8379, 0.8370, 0.8374, 0.8372]

val_f1 = [0.8405, 0.8454, 0.8600, 0.8545, 0.8611, 0.8815, 0.8677, 0.8701, 0.8822, 0.8659, 
          0.8755, 0.8852, 0.8894, 0.8932, 0.8954, 0.8970, 0.8942, 0.8951, 0.8974, 0.8967, 
          0.8975, 0.8984, 0.8975, 0.8979, 0.8979]

val_recall = [0.8730, 0.8924, 0.8795, 0.9186, 0.8457, 0.8874, 0.8537, 0.8380, 0.8979, 0.8426, 
              0.9011, 0.8930, 0.9046, 0.8843, 0.8959, 0.8990, 0.8999, 0.9011, 0.9045, 0.8937, 
              0.8973, 0.9034, 0.8994, 0.9020, 0.9019]

val_precision = [0.8474, 0.8480, 0.8762, 0.8428, 0.9309, 0.9123, 0.9265, 0.9513, 0.9092, 0.9393, 
                 0.8965, 0.9158, 0.9112, 0.9369, 0.9290, 0.9284, 0.9240, 0.9241, 0.9251, 0.9344, 
                 0.9321, 0.9272, 0.9304, 0.9281, 0.9281]

# %%
import matplotlib.pyplot as plt

def plot_losses(train_loss, val_loss):
    epochs = range(1, len(train_loss) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_loss, 'b-o', label='Train Loss')
    plt.plot(epochs, val_loss, 'r-o', label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('PVTResAdapNet Train and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_jaccard(train_jaccard, val_jaccard):
    epochs = range(1, len(train_jaccard) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_jaccard, 'b-o', label='Train Jaccard Index')
    plt.plot(epochs, val_jaccard, 'r-o', label='Validation Jaccard Index')
    plt.xlabel('Epochs')
    plt.ylabel('Jaccard Index')
    plt.title('PVTResAdapNet Train and Validation Jaccard Index')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_f1(train_f1, val_f1):
    epochs = range(1, len(train_f1) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_f1, 'b-o', label='Train F1 Score')
    plt.plot(epochs, val_f1, 'r-o', label='Validation F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.title('PVTResAdapNet Train and Validation F1 Score')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_recall(train_recall, val_recall):
    epochs = range(1, len(train_recall) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_recall, 'b-o', label='Train Recall')
    plt.plot(epochs, val_recall, 'r-o', label='Validation Recall')
    plt.xlabel('Epochs')
    plt.ylabel('Recall')
    plt.title('PVTResAdapNet Train and Validation Recall')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_precision(train_precision, val_precision):
    epochs = range(1, len(train_precision) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_precision, 'b-o', label='Train Precision')
    plt.plot(epochs, val_precision, 'r-o', label='Validation Precision')
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.title('PVTResAdapNet Train and Validation Precision')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:

# %%
plot_losses(train_loss, val_loss)

# %%
plot_jaccard(train_jaccard, val_jaccard)

# %%
plot_f1(train_f1, val_f1)
