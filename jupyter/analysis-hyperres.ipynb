# %%
# Train Metrics
train_loss = [0.4164, 0.3730, 0.3316, 0.2854, 0.2862, 0.2568, 0.2418, 0.2061, 0.1987, 0.2036, 
              0.1782, 0.1674, 0.1538, 0.1561, 0.1389, 0.1297, 0.1220, 0.1222, 0.1162, 0.1133, 
              0.1148, 0.1134, 0.1130, 0.1114, 0.1077, 0.1083]

train_jaccard = [0.7965, 0.8024, 0.8133, 0.8296, 0.8241, 0.8336, 0.8354, 0.8550, 0.8546, 0.8483, 
                 0.8628, 0.8671, 0.8749, 0.8747, 0.8816, 0.8892, 0.8944, 0.8931, 0.8994, 0.8971, 
                 0.8998, 0.8973, 0.8996, 0.9026, 0.9020, 0.9027]

train_f1 = [0.8727, 0.8764, 0.8853, 0.8967, 0.8917, 0.8995, 0.8986, 0.9148, 0.9139, 0.9083, 
            0.9204, 0.9223, 0.9283, 0.9260, 0.9331, 0.9375, 0.9408, 0.9398, 0.9447, 0.9424, 
            0.9452, 0.9423, 0.9442, 0.9468, 0.9453, 0.9461]

train_recall = [0.8886, 0.8888, 0.8970, 0.9024, 0.9007, 0.9050, 0.9041, 0.9154, 0.9132, 0.9109, 
                0.9214, 0.9214, 0.9251, 0.9255, 0.9299, 0.9353, 0.9401, 0.9374, 0.9415, 0.9382, 
                0.9417, 0.9399, 0.9415, 0.9409, 0.9393, 0.9429]

train_precision = [0.8892, 0.8971, 0.8992, 0.9153, 0.9101, 0.9138, 0.9186, 0.9288, 0.9324, 0.9260, 
                   0.9322, 0.9381, 0.9421, 0.9382, 0.9445, 0.9480, 0.9490, 0.9503, 0.9528, 0.9526, 
                   0.9528, 0.9521, 0.9527, 0.9568, 0.9577, 0.9545]

# Validation Metrics
val_loss = [0.3478, 0.2993, 0.2829, 0.2645, 0.2638, 0.2343, 0.2252, 0.2563, 0.2066, 0.2490, 
            0.2067, 0.2299, 0.2394, 0.2107, 0.2163, 0.1796, 0.1782, 0.1819, 0.1856, 0.1815, 
            0.1789, 0.1748, 0.1829, 0.1833, 0.1838, 0.1843]

val_jaccard = [0.7963, 0.7992, 0.8092, 0.8148, 0.8094, 0.8215, 0.8229, 0.8158, 0.8287, 0.8146, 
               0.8303, 0.8240, 0.8242, 0.8388, 0.8404, 0.8510, 0.8501, 0.8495, 0.8502, 0.8530, 
               0.8534, 0.8537, 0.8531, 0.8527, 0.8542, 0.8545]

val_f1 = [0.8712, 0.8704, 0.8765, 0.8822, 0.8780, 0.8876, 0.8882, 0.8774, 0.8923, 0.8828, 
          0.8930, 0.8883, 0.8852, 0.8987, 0.8999, 0.9082, 0.9078, 0.9069, 0.9070, 0.9090, 
          0.9091, 0.9098, 0.9085, 0.9083, 0.9096, 0.9096]

# %%
import matplotlib.pyplot as plt

def plot_losses(train_loss, val_loss):
    epochs = range(1, len(train_loss) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_loss, 'b-o', label='Train Loss')
    plt.plot(epochs, val_loss, 'r-o', label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('HyperRes Train and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_jaccard(train_jaccard, val_jaccard):
    epochs = range(1, len(train_jaccard) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_jaccard, 'b-o', label='Train Jaccard Index')
    plt.plot(epochs, val_jaccard, 'r-o', label='Validation Jaccard Index')
    plt.xlabel('Epochs')
    plt.ylabel('Jaccard Index')
    plt.title('HyperRes Train and Validation Jaccard Index')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_f1(train_f1, val_f1):
    epochs = range(1, len(train_f1) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_f1, 'b-o', label='Train F1 Score')
    plt.plot(epochs, val_f1, 'r-o', label='Validation F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.title('HyperRes Train and Validation F1 Score')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_recall(train_recall, val_recall):
    epochs = range(1, len(train_recall) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_recall, 'b-o', label='Train Recall')
    plt.plot(epochs, val_recall, 'r-o', label='Validation Recall')
    plt.xlabel('Epochs')
    plt.ylabel('Recall')
    plt.title('HyperRes Train and Validation Recall')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_precision(train_precision, val_precision):
    epochs = range(1, len(train_precision) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_precision, 'b-o', label='Train Precision')
    plt.plot(epochs, val_precision, 'r-o', label='Validation Precision')
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.title('HyperRes Train and Validation Precision')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:

# %%
plot_losses(train_loss, val_loss)

# %%
plot_jaccard(train_jaccard, val_jaccard)

# %%
plot_f1(train_f1, val_f1)
