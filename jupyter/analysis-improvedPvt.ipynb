# %%
# Train Metrics
train_loss = [0.0996, 0.1244, 0.1193, 0.1006, 0.0998, 0.1055, 0.1068, 0.1082, 0.0971, 0.0820, 
              0.0731, 0.0763, 0.0878, 0.0956, 0.1029, 0.0792, 0.0810, 0.0735, 0.0728, 0.0669, 
              0.0641, 0.0652, 0.0640, 0.0634, 0.0661, 0.0649]

train_jaccard = [0.8993, 0.8824, 0.8866, 0.8983, 0.9010, 0.8978, 0.8963, 0.8977, 0.9031, 0.9127, 
                 0.9173, 0.9132, 0.9078, 0.9037, 0.9002, 0.9157, 0.9161, 0.9205, 0.9169, 0.9234, 
                 0.9266, 0.9236, 0.9261, 0.9265, 0.9272, 0.9262]

train_f1 = [0.9437, 0.9314, 0.9339, 0.9432, 0.9438, 0.9413, 0.9419, 0.9420, 0.9461, 0.9523, 
            0.9550, 0.9514, 0.9477, 0.9462, 0.9439, 0.9538, 0.9545, 0.9574, 0.9535, 0.9585, 
            0.9602, 0.9582, 0.9599, 0.9600, 0.9608, 0.9598]

train_recall = [0.9368, 0.9294, 0.9322, 0.9356, 0.9395, 0.9353, 0.9374, 0.9371, 0.9392, 0.9469, 
                0.9494, 0.9443, 0.9425, 0.9409, 0.9365, 0.9488, 0.9499, 0.9514, 0.9439, 0.9510, 
                0.9547, 0.9506, 0.9540, 0.9541, 0.9588, 0.9550]

train_precision = [0.9576, 0.9480, 0.9486, 0.9578, 0.9568, 0.9580, 0.9536, 0.9557, 0.9587, 0.9619, 
                   0.9635, 0.9640, 0.9599, 0.9584, 0.9599, 0.9628, 0.9631, 0.9661, 0.9689, 0.9694, 
                   0.9690, 0.9701, 0.9695, 0.9694, 0.9654, 0.9671]

# Validation Metrics
val_loss = [0.2088, 0.2802, 0.2091, 0.2105, 0.2018, 0.2475, 0.2045, 0.2662, 0.1977, 0.1965, 
            0.1999, 0.1930, 0.2565, 0.2258, 0.2270, 0.2488, 0.2305, 0.2329, 0.2087, 0.2077, 
            0.2392, 0.2301, 0.2254, 0.2251, 0.2240, 0.2255]

val_jaccard = [0.8364, 0.8149, 0.8399, 0.8423, 0.8475, 0.8231, 0.8488, 0.8237, 0.8460, 0.8535, 
               0.8551, 0.8532, 0.8264, 0.8374, 0.8341, 0.8273, 0.8378, 0.8353, 0.8468, 0.8481, 
               0.8397, 0.8417, 0.8447, 0.8444, 0.8453, 0.8463]

val_f1 = [0.8969, 0.8813, 0.9013, 0.9012, 0.9050, 0.8855, 0.9055, 0.8846, 0.9016, 0.9081, 
          0.9110, 0.9084, 0.8877, 0.8971, 0.8939, 0.8868, 0.8978, 0.8938, 0.9034, 0.9047, 
          0.8959, 0.8980, 0.9012, 0.9009, 0.9018, 0.9027]

# %%
import matplotlib.pyplot as plt

def plot_losses(train_loss, val_loss):
    epochs = range(1, len(train_loss) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_loss, 'b-o', label='Train Loss')
    plt.plot(epochs, val_loss, 'r-o', label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('ImprovedPvt Train and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_jaccard(train_jaccard, val_jaccard):
    epochs = range(1, len(train_jaccard) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_jaccard, 'b-o', label='Train Jaccard Index')
    plt.plot(epochs, val_jaccard, 'r-o', label='Validation Jaccard Index')
    plt.xlabel('Epochs')
    plt.ylabel('Jaccard Index')
    plt.title('ImprovedPvt Train and Validation Jaccard Index')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_f1(train_f1, val_f1):
    epochs = range(1, len(train_f1) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_f1, 'b-o', label='Train F1 Score')
    plt.plot(epochs, val_f1, 'r-o', label='Validation F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.title('ImprovedPvt Train and Validation F1 Score')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_recall(train_recall, val_recall):
    epochs = range(1, len(train_recall) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_recall, 'b-o', label='Train Recall')
    plt.plot(epochs, val_recall, 'r-o', label='Validation Recall')
    plt.xlabel('Epochs')
    plt.ylabel('Recall')
    plt.title('ImprovedPvt Train and Validation Recall')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_precision(train_precision, val_precision):
    epochs = range(1, len(train_precision) + 1)
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, train_precision, 'b-o', label='Train Precision')
    plt.plot(epochs, val_precision, 'r-o', label='Validation Precision')
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.title('ImprovedPvt Train and Validation Precision')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:

# %%
plot_losses(train_loss, val_loss)

# %%
plot_jaccard(train_jaccard, val_jaccard)

# %%
plot_f1(train_f1, val_f1)
